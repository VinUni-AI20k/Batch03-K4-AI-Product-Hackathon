# %% [markdown]
# # Kết quả Khảo sát thực tế

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Câu trả lời.xlsx")
df1.columns
# Out:
# Index(['Dấu thời gian',
#        '1. Bạn đánh giá thế nào về tính năng khoanh vùng văn bản hoặc hình ảnh trực tiếp trên slide ở trên Vlearn để trợ lý AI giải đáp?',
#        '2. Nếu câu trả lời của AI chưa đủ rõ, việc hệ thống cung cấp thêm các đường link tài liệu liên quan có thực sự hữu ích với bạn không?',
#        '3. Bạn có sẵn sàng làm một bài Quiz ngắn ngay sau đó để hệ thống kiểm tra lại mức độ hiểu bài của mình?',
#        '4.  Bạn cảm thấy thế nào nếu hệ thống tự động chuyển câu hỏi và vùng slide bạn chưa hiểu cho giảng viên khi bạn làm Quiz không đạt?',
#        '5.  Bạn thấy toàn bộ quy trình xử lý (Hỏi AI -> Đọc tài liệu -> Làm Quiz -> Nhờ Giảng viên) có làm bạn cảm thấy mất thời gian hay phức tạp không?',
#        '6.  Bạn muốn thay đổi hoặc lược bỏ bước nào trong quy trình trên để trải nghiệm học tập được trơn tru hơn?',
#        '7. Nếu hệ thống hỗ trợ tích hợp thêm tính năng thảo luận nhóm với những bạn cùng gặp khó khăn tại slide đó, bạn có tham gia không?',
# ...

# %%
df1['4.  Bạn cảm thấy thế nào nếu hệ thống tự động chuyển câu hỏi và vùng slide bạn chưa hiểu cho giảng viên khi bạn làm Quiz không đạt?'].value_counts()
# Out:
# 4.  Bạn cảm thấy thế nào nếu hệ thống tự động chuyển câu hỏi và vùng slide bạn chưa hiểu cho giảng viên khi bạn làm Quiz không đạt?
# Rất đồng tình, giúp tôi giải quyết triệt để vấn đề.                            18
# Cần hệ thống hỏi ý kiến (nút "Đồng ý gửi") trước khi chuyển cho giảng viên.    14
# Không thoải mái, tôi sợ bị giảng viên đánh giá.                                 4
# Name: count, dtype: int64

# %%
(18+14)/36
# Out:
# 0.8888888888888888

# %%
df1['9. Bạn có sẵn sàng chia sẻ lịch sử lỗi sai của mình với AI để hệ thống gợi ý các chủ đề cần ôn luyện lại không?'].value_counts()
# Out:
# 9. Bạn có sẵn sàng chia sẻ lịch sử lỗi sai của mình với AI để hệ thống gợi ý các chủ đề cần ôn luyện lại không?
# 5    16
# 4     9
# 3     8
# 2     2
# 1     1
# Name: count, dtype: int64

# %%
(16+9+8)/36
# Out:
# 0.9166666666666666

# %%
df1['4.  Bạn cảm thấy thế nào nếu hệ thống tự động chuyển câu hỏi và vùng slide bạn chưa hiểu cho giảng viên khi bạn làm Quiz không đạt?'].value_counts()
# Out:
# 4.  Bạn cảm thấy thế nào nếu hệ thống tự động chuyển câu hỏi và vùng slide bạn chưa hiểu cho giảng viên khi bạn làm Quiz không đạt?
# Rất đồng tình, giúp tôi giải quyết triệt để vấn đề.                            18
# Cần hệ thống hỏi ý kiến (nút "Đồng ý gửi") trước khi chuyển cho giảng viên.    14
# Không thoải mái, tôi sợ bị giảng viên đánh giá.                                 4
# Name: count, dtype: int64

# %%
(18+14)/36
# Out:
# 0.8888888888888888

# %% [markdown]
# # `chat_history_anonymized_for_hackathon.csv`

# %%
df2 = pd.read_csv("../data/vlearn-pack/chatlog/chat_history_anonymized_for_hackathon.csv")
df2.columns
# Out:
# Index(['conversation_id', 'user_id', 'day_code', 'conversation_mode',
#        'turn_id', 'turn_status', 'message_id', 'role', 'content', 'move_used',
#        'citations', 'misconceptions', 'follow_ups', 'rating',
#        'asked_check_question', 'message_created_at', 'llm_call_count',
#        'models_used', 'total_input_tokens', 'total_output_tokens',
#        'total_cost_usd', 'avg_latency_ms'],
#       dtype='object')

# %%
df2['asked_check_question'].value_counts()
# Out:
# asked_check_question
# False    2519
# True        3
# Name: count, dtype: int64

# %%
df2['misconceptions'].value_counts()
# Out:
# misconceptions
# []    1261
# Name: count, dtype: int64
